# %%
import pandas as pd

# %%
ZomatoData = pd.read_csv('zomato.csv',encoding = 'unicode_escape')
ZomatoData = ZomatoData.drop_duplicates().reset_index(drop=True)
ZomatoData['City']= ZomatoData['City'].apply(lambda s:s.lower() if type(s) == str else s)
ZomatoData['Cuisines']= ZomatoData['Cuisines'].apply(lambda s:s.lower() if type(s) == str else s)
ZomatoData['City'] = ZomatoData['City'].apply(lambda s:'nashik' if s=='nasik' else s)
ZomatoData['Price_Range'] = ZomatoData['Average Cost for two'].apply(lambda x: 'low' if x<300 else ('mid' if 300<=x<700 else 'high'))

# %%
ZomatoData['Price_Range'].value_counts()
# Out:
# mid     4797
# high    2658
# low     1896
# Name: Price_Range, dtype: int64

# %%
price='211'
if price not in ['high','mid','low'] and price.isnumeric():
    price=int(price)
    if price <300:price='low'
    elif price>700:price='high'
    else: price='medium'
        
price
# Out:
# 'low'

# %%
data = ZomatoData.loc[(ZomatoData['City']=='new delhi') & (ZomatoData['Price_Range']=='low') & (ZomatoData['Cuisines'].str.contains('chinese')),['Restaurant Name','Address','Aggregate rating']].sort_values(by='Aggregate rating',ascending=False).head(5)

# %%
data.values.tolist()
# Out:
# [['Panchwati Rasoi', 'LSC, Savita Vihar Market, Anand Vihar, New Delhi', 3.8],
#  ['Manohar Bikkaneri', '1512, Clock Tower, Near, Kamla Nagar, New Delhi', 3.8],
#  ['Suresh Fast Food',
#   '5, DDA Market, Hudson Lane, Kingsway Camp, Delhi University-GTB Nagar, New Delhi',
#   3.7],
#  ['Manohar Bikkaneri',
#   '2, UA, Jawahar Nagar, Near Malkaganj Chowk, Kamla Nagar, New Delhi',
#   3.6],
#  ['Gaurav Pastry Palace', 'G-20/224-225, Rohini, New Delhi', 3.6]]

# %%
ZomatoData.loc[ZomatoData['Cuisines'].str.contains('north indian'),:]
# Out:
#       Restaurant ID                 Restaurant Name  Country Code   City  \
# 0           3400025                      Jahanpanah             1   agra
# 1           3400341             Rangrezz Restaurant             1   agra
# 2           3400005         Time2Eat - Mama Chicken             1   agra
# 3           3400005  Mama Chicken Mama Franky House             1   agra
# 5           3400017                  Pinch Of Spice             1   agra
# ...             ...                             ...           ...    ...
# 9343        2800868                  Raju's Kitchen             1  vizag
# 9344        2800418                        Kaloreez             1  vizag
# 9345        2800856                 Barbeque Nation             1  vizag
# 9347        2800042                Vista - The Park             1  vizag
# 9349        2800901                Paradise Biryani             1  vizag
#
#                                                 Address  \
# ...

# %%
ZomatoData.City.unique()
# Out:
# array(['agra', 'ahmedabad', 'allahabad', 'amritsar', 'aurangabad',
#        'bangalore', 'bhopal', 'bhubaneshwar', 'chandigarh', 'chennai',
#        'coimbatore', 'dehradun', 'faridabad', 'gangtok', 'ghaziabad',
#        'goa', 'gurgaon', 'guwahati', 'hyderabad', 'indore', 'jaipur',
#        'kanpur', 'kochi', 'kolkata', 'lucknow', 'ludhiana', 'mangalore',
#        'mohali', 'mumbai', 'mysore', 'nagpur', 'nashik', 'new delhi',
#        'noida', 'ooty', 'panchkula', 'patna', 'puducherry', 'pune',
#        'ranchi', 'secunderabad', 'shimla', 'surat', 'vadodara',
#        'varanasi', 'vizag'], dtype=object)

# %%
WeOperate = ['New Delhi', 'Gurgaon', 'Noida', 'Faridabad', 'Allahabad', 'Bhubaneshwar', 'Mangalore', 'Mumbai', 'Ranchi', 'Patna', 'Mysore', 'Aurangabad', 'Amritsar', 'Puducherry', 'Varanasi', 'Nagpur', 'Vadodara', 'Dehradun', 'Vizag', 'Agra', 'Ludhiana', 'Kanpur', 'Lucknow', 'Surat', 'Kochi', 'Indore', 'Ahmedabad', 'Coimbatore', 'Chennai', 'Guwahati', 'Jaipur', 'Hyderabad', 'Bangalore', 'Nashik', 'Pune', 'Kolkata', 'Bhopal', 'Goa', 'Chandigarh', 'Ghaziabad', 'Ooty', 'Gangtok', 'Shimla']

# %%
WeOperate
# Out:
# ['New Delhi',
#  'Gurgaon',
#  'Noida',
#  'Faridabad',
#  'Allahabad',
#  'Bhubaneshwar',
#  'Mangalore',
#  'Mumbai',
#  'Ranchi',
#  'Patna',
#  'Mysore',
#  'Aurangabad',
#  'Amritsar',
#  'Puducherry',
#  'Varanasi',
#  'Nagpur',
#  'Vadodara',
#  'Dehradun',
#  'Vizag',
#  'Agra',
#  'Ludhiana',
#  'Kanpur',
#  'Lucknow',
#  'Surat',
#  'Kochi',
#  'Indore',
#  'Ahmedabad',
#  'Coimbatore',
#  'Chennai',
#  'Guwahati',
#  'Jaipur',
#  'Hyderabad',
#  'Bangalore',
#  'Nashik',
#  'Pune',
#  'Kolkata',
#  'Bhopal',
#  'Goa',
#  'Chandigarh',
#  'Ghaziabad',
#  'Ooty',
#  'Gangtok',
#  'Shimla']

# %%
we = list(map(str.lower,WeOperate))

city for city in list(ZomatoData.City.unique()) if city not in we]

# %%
filter(lambda x: x if x not in we,ZomatoData.City.unique())
# Out:
#   File "<ipython-input-39-fb1c4159e635>", line 1
#     filter(lambda x: x if x not in we,ZomatoData.City.unique())
#                                      ^
# SyntaxError: invalid syntax

# %%
x=[]
for city in list(ZomatoData.City.unique()):
    if city not in we:
        x.append(city)
x
# Out:
# ['mohali', 'nasik', 'panchkula', 'secunderabad']

# %%
ZomatoData.loc[ZomatoData.City.isin(x),:]
# Out:
#       Restaurant ID       Restaurant Name  Country Code          City  \
# 2273         123789          amigo's cafe             1        mohali
# 2274         120154          katani dhaba             1        mohali
# 2275         123013          amrit sweets             1        mohali
# 2276         120160          khalsa dhaba             1        mohali
# 2277         124184        pizza freakerz             1        mohali
# 2278       18424018     the shooters cafe             1        mohali
# 2434        1600099          kokni darbar             1         nasik
# 2435       18839989  samarth juice center             1         nasik
# 9017       18609823    falcon cafe lounge             1     panchkula
# 9018         120519         hops n grains             1     panchkula
# 9174          96814        saffron mantra             1  secunderabad
# 9175          90499            coffee cup             1  secunderabad
#
# ...

# %%
ZomatoData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9351 entries, 0 to 9350
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9351 non-null   int64
#  1   Restaurant Name       9351 non-null   object
#  2   Country Code          9351 non-null   int64
#  3   City                  9351 non-null   object
#  4   Address               9351 non-null   object
#  5   Locality              9351 non-null   object
#  6   Locality Verbose      9351 non-null   object
#  7   Longitude             9351 non-null   float64
#  8   Latitude              9351 non-null   float64
#  9   Cuisines              9351 non-null   object
#  10  Average Cost for two  9351 non-null   int64
#  11  Currency              9351 non-null   object
#  12  Has Table booking     9351 non-null   int64
#  13  Has Online delivery   9351 non-null   int64
#  14  Is delivering now     9351 non-null   int64
# ...

# %%
ZomatoData['Aggregate rating'].value_counts()
# Out:
# 0.0    2138
# 3.1     511
# 3.2     511
# 3.4     482
# 3.3     474
# 3.0     465
# 3.5     453
# 3.6     415
# 2.9     381
# 3.7     371
# 3.8     352
# 2.8     315
# 3.9     311
# 4.2     283
# 4.1     277
# 4.3     265
# 2.7     250
# 4.0     237
# 2.6     190
# 4.4     151
# 2.5     109
# 4.5     109
# 2.4      82
# 4.6      57
# 2.3      48
# 4.7      26
# 2.2      26
# 4.9      25
# 2.1      15
# 4.8      12
# 2.0       7
# 1.9       2
# 1.8       1
# Name: Aggregate rating, dtype: int64
